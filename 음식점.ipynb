# %%
import pandas as pd
import json
food=pd.read_csv('./서울시 식품위생업소 (층) 현황.csv',encoding='EUC-KR')

foodG=food[food['시군구코드'] == 3040000]

# %%
foodG
# Out:
#           시군구코드            업종명            업태명     허가신고일  폐업일자         교부번호  \
# 1       3040000          일반음식점             기타  20230327   NaN  20230053299
# 3       3040000          휴게음식점       기타 휴게음식점  20230327   NaN  20230053301
# 7       3040000          휴게음식점            편의점  20230327   NaN  20230053304
# 14      3040000          휴게음식점            커피숍  20230327   NaN  20230053300
# 22      3040000  건강기능식품유통전문판매업  건강기능식품유통전문판매업  20230327   NaN  20230053303
# ...         ...            ...            ...       ...   ...          ...
# 261382  3040000         유흥주점영업            룸살롱  19760223   NaN  19760039006
# 261473  3040000         유흥주점영업            룸살롱  19741019   NaN  19740039005
# 261651  3040000      즉석판매제조가공업      즉석판매제조가공업  19721017   NaN  19720039007
# 261666  3040000         유흥주점영업        비어(바)살롱  19720804   NaN  19720039006
# 261686  3040000      즉석판매제조가공업      즉석판매제조가공업  19720516   NaN  19720039003
#
#                   업소명                                  소재지도로명  \
# ...

# %%
foodG['도로명']=foodG['소재지지번'].apply(lambda x: str(x).split(',')[0])

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
foodG['도로명'].value_counts()
# Out:
# 서울특별시 광진구 구의동  546번지 4호  테크노-마트21                        26
# 서울특별시 광진구 화양동  33번지 34호                                  24
# 서울특별시 광진구 자양동  227번지 7호  더샵스타시티                          24
# 서울특별시 광진구 자양동  227번지 342호  롯데백화점                         21
# 서울특별시 광진구 군자동  125번지 212호                                20
# 서울특별시 광진구 자양동  859번지  래미안프리미어팰리스                         18
# 서울특별시 광진구 구의동  546번지 4호                                  16
# 서울특별시 광진구 화양동  113번지 1호  광진 코지웰                          11
# 서울특별시 광진구 자양동  227번지 7호                                  11
# 서울특별시 광진구 자양동  227번지 342호  롯데백화점 지하1층                    11
# 서울특별시 광진구 자양동  227번지 342호                                10
# 서울특별시 광진구 광장동  산 21번지                                    10
# 서울특별시 광진구 구의동  631번지 1호  현대프라임아파트                         9
# 서울특별시 광진구 광장동  210번지 1호  다움앤다움 빌딩                         9
# 서울특별시 광진구 구의동  667번지  강변에스케이뷰                             9
# 서울특별시 광진구 화양동  1번지  건국대학교                                 9
# ...
